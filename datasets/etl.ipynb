# %%
import pandas as pd
import datetime as dt

# %%
url = 'https://raw.githubusercontent.com/leilaff89/house_sales_prediction/main/datasets/all_perth_310121.csv'

# %%
df = pd.read_csv(url)

# %%
df['DATE_SOLD'] = df['DATE_SOLD'].map(lambda x: x.rstrip('\r'))
df['MONTH_SOLD'] = pd.to_datetime(df.DATE_SOLD).dt.strftime('%m')
df['YEAR_SOLD'] = pd.to_datetime(df.DATE_SOLD).dt.strftime('%Y')
df['BUILD_YEAR'] = pd.to_datetime(df.BUILD_YEAR).dt.strftime('%Y')
df.drop('DATE_SOLD', axis='columns', inplace=True)
df = df[df['BATHROOMS']<15]
df = df[df['GARAGE']<=10]

# %%
df.head()
# Out:
#            ADDRESS      SUBURB   PRICE  BEDROOMS  BATHROOMS  GARAGE  \
# 0    1 Acorn Place  South Lake  565000         4          2     2.0
# 1      1 Addis Way       Wandi  365000         3          2     2.0
# 2  1 Ainsley Court     Camillo  287000         3          1     1.0
# 3  1 Albert Street    Bellevue  255000         2          1     2.0
# 4     1 Aman Place   Lockridge  325000         4          1     2.0
#
#    LAND_AREA  FLOOR_AREA BUILD_YEAR  CBD_DIST               NEAREST_STN  \
# 0        600         160       1970     18300  Cockburn Central Station
# 1        351         139       1970     26900           Kwinana Station
# 2        719          86       1970     22600           Challis Station
# 3        651          59       1970     17900           Midland Station
# 4        466         131       1970     11200        Bassendean Station
#
#    NEAREST_STN_DIST  POSTCODE   LATITUDE   LONGITUDE  \
# 0              1800      6164 -32.115900  115.842450
# 1              4900      6167 -32.193470  115.859554
# 2              1900      6111 -32.120578  115.993579
# 3              3600      6056 -31.900547  116.038009
# 4              2000      6054 -31.885790  115.947780
#
#                     NEAREST_SCH  NEAREST_SCH_DIST  NEAREST_SCH_RANK  \
# 0   LAKELAND SENIOR HIGH SCHOOL          0.828339               NaN
# 1                ATWELL COLLEGE          5.524324             129.0
# 2  KELMSCOTT SENIOR HIGH SCHOOL          1.649178             113.0
# 3  SWAN VIEW SENIOR HIGH SCHOOL          1.571401               NaN
# 4                 KIARA COLLEGE          1.514922               NaN
#
#   MONTH_SOLD YEAR_SOLD
# 0         09      2018
# 1         02      2019
# 2         06      2015
# 3         07      2018
# 4         11      2016

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31101 entries, 0 to 33655
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ADDRESS           31101 non-null  object
#  1   SUBURB            31101 non-null  object
#  2   PRICE             31101 non-null  int64
#  3   BEDROOMS          31101 non-null  int64
#  4   BATHROOMS         31101 non-null  int64
#  5   GARAGE            31101 non-null  float64
#  6   LAND_AREA         31101 non-null  int64
#  7   FLOOR_AREA        31101 non-null  int64
#  8   BUILD_YEAR        28191 non-null  object
#  9   CBD_DIST          31101 non-null  int64
#  10  NEAREST_STN       31101 non-null  object
#  11  NEAREST_STN_DIST  31101 non-null  int64
#  12  POSTCODE          31101 non-null  int64
#  13  LATITUDE          31101 non-null  float64
#  14  LONGITUDE         31101 non-null  float64
#  15  NEAREST_SCH       31101 non-null  object
#  16  NEAREST_SCH_DIST  31101 non-null  float64
#  17  NEAREST_SCH_RANK  21027 non-null  float64
#  18  MONTH_SOLD        31101 non-null  object
#  19  YEAR_SOLD         31101 non-null  object
# dtypes: float64(5), int64(8), object(7)
# memory usage: 5.0+ MB

# %%
df.to_csv('house_prices_complete.csv', index=False)

# %%
df_no_null = df.dropna()
df_no_null.head()
# Out:
#                  ADDRESS        SUBURB  ...  MONTH_SOLD  YEAR_SOLD
# 1            1 Addis Way         Wandi  ...          02       2019
# 2        1 Ainsley Court       Camillo  ...          06       2015
# 9       1 Arundel Street     Bayswater  ...          10       2019
# 11        1 Ashcott Gate        Butler  ...          11       2018
# 13  1 Ashendon Boulevard  Hammond Park  ...          07       2019
#
# [5 rows x 20 columns]

# %%
df_no_null.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19174 entries, 1 to 33651
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ADDRESS           19174 non-null  object
#  1   SUBURB            19174 non-null  object
#  2   PRICE             19174 non-null  int64
#  3   BEDROOMS          19174 non-null  int64
#  4   BATHROOMS         19174 non-null  int64
#  5   GARAGE            19174 non-null  float64
#  6   LAND_AREA         19174 non-null  int64
#  7   FLOOR_AREA        19174 non-null  int64
#  8   BUILD_YEAR        19174 non-null  object
#  9   CBD_DIST          19174 non-null  int64
#  10  NEAREST_STN       19174 non-null  object
#  11  NEAREST_STN_DIST  19174 non-null  int64
#  12  POSTCODE          19174 non-null  int64
#  13  LATITUDE          19174 non-null  float64
#  14  LONGITUDE         19174 non-null  float64
#  15  NEAREST_SCH       19174 non-null  object
#  16  NEAREST_SCH_DIST  19174 non-null  float64
#  17  NEAREST_SCH_RANK  19174 non-null  float64
#  18  MONTH_SOLD        19174 non-null  object
#  19  YEAR_SOLD         19174 non-null  object
# dtypes: float64(5), int64(8), object(7)
# memory usage: 3.1+ MB

# %%
df_no_null.to_csv('house_prices_no_null.csv', index=False)
